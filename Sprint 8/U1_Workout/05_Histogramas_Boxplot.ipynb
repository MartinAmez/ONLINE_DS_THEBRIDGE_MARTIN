# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

data=np.random.randn(1000)

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(data)
# Out:
# (array([  8.,  27.,  89., 165., 235., 213., 142.,  86.,  30.,   5.]),
#  array([-2.89622964, -2.3144857 , -1.73274176, -1.15099782, -0.56925388,
#          0.01249006,  0.59423399,  1.17597793,  1.75772187,  2.33946581,
#          2.92120975]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure(figsize=(4.5,3))
ax = plt.axes()
ax.hist(data)
# Out:
# (array([  8.,  27.,  89., 165., 235., 213., 142.,  86.,  30.,   5.]),
#  array([-2.89622964, -2.3144857 , -1.73274176, -1.15099782, -0.56925388,
#          0.01249006,  0.59423399,  1.17597793,  1.75772187,  2.33946581,
#          2.92120975]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(data,
         bins=50,
         alpha=1,
         color="steelblue");

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1,**kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([  2.,   2.,   7.,  13.,  19.,  28.,  58.,  69.,  98.,  95., 120.,
#         105., 110.,  91.,  76.,  42.,  25.,  21.,  13.,   6.]),
#  array([-3.61604219, -3.00736651, -2.39869084, -1.79001516, -1.18133948,
#         -0.57266381,  0.03601187,  0.64468755,  1.25336322,  1.8620389 ,
#          2.47071458,  3.07939025,  3.68806593,  4.29674161,  4.90541728,
#          5.51409296,  6.12276864,  6.73144431,  7.34011999,  7.94879567,
#          8.55747134]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.Figure()
ax = plt.axes()
limites=ax.hist(x1, alpha=0.3, bins=30)

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites[0] # valores
# Out:
# array([ 2.,  1.,  6., 11.,  8., 15., 18., 43., 46., 43., 70., 55., 65.,
#        72., 53., 83., 59., 35., 78., 59., 36., 40., 36., 21., 19.,  9.,
#         6.,  6.,  4.,  1.])

# %%
limites[1] # intervalos
# Out:
# array([-2.28231278, -2.13185568, -1.98139858, -1.83094148, -1.68048438,
#        -1.53002728, -1.37957018, -1.22911308, -1.07865598, -0.92819888,
#        -0.77774178, -0.62728468, -0.47682758, -0.32637049, -0.17591339,
#        -0.02545629,  0.12500081,  0.27545791,  0.42591501,  0.57637211,
#         0.72682921,  0.87728631,  1.02774341,  1.17820051,  1.32865761,
#         1.47911471,  1.62957181,  1.78002891,  1.930486  ,  2.0809431 ,
#         2.2314002 ])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt.boxplot(data,whis=1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x157eeb7d9d0>,
#   <matplotlib.lines.Line2D at 0x157eeb7e650>],
#  'caps': [<matplotlib.lines.Line2D at 0x157eeb7f0d0>,
#   <matplotlib.lines.Line2D at 0x157eeb7fd90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x157eed46f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x157eeb80a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x157eeb815d0>],
#  'means': []}

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(data,vert=False,whis=1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x157eef35e50>,
#   <matplotlib.lines.Line2D at 0x157eef36b10>],
#  'caps': [<matplotlib.lines.Line2D at 0x157eef37690>,
#   <matplotlib.lines.Line2D at 0x157eef44110>],
#  'boxes': [<matplotlib.lines.Line2D at 0x157eef35510>],
#  'medians': [<matplotlib.lines.Line2D at 0x157eef44bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x157eef45690>],
#  'means': []}

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt.boxplot([x1,x2,x3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x157ef0ad090>,
#   <matplotlib.lines.Line2D at 0x157ef0adb90>,
#   <matplotlib.lines.Line2D at 0x157ef0b9bd0>,
#   <matplotlib.lines.Line2D at 0x157ef0ba690>,
#   <matplotlib.lines.Line2D at 0x157ef0c6790>,
#   <matplotlib.lines.Line2D at 0x157ef0c7250>],
#  'caps': [<matplotlib.lines.Line2D at 0x157ef0ae790>,
#   <matplotlib.lines.Line2D at 0x157ef0af1d0>,
#   <matplotlib.lines.Line2D at 0x157ef0bb110>,
#   <matplotlib.lines.Line2D at 0x157ef0bbbd0>,
#   <matplotlib.lines.Line2D at 0x157ef0c7cd0>,
#   <matplotlib.lines.Line2D at 0x157ef0d0750>],
#  'boxes': [<matplotlib.lines.Line2D at 0x157eef5b210>,
#   <matplotlib.lines.Line2D at 0x157ef0b9110>,
#   <matplotlib.lines.Line2D at 0x157ef0c5cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x157ef0afc50>,
#   <matplotlib.lines.Line2D at 0x157ef0c46d0>,
#   <matplotlib.lines.Line2D at 0x157ef0d1190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x157ef0b8710>,
#   <matplotlib.lines.Line2D at 0x157ef0c51d0>,
#   <matplotlib.lines.Line2D at 0x157ef0d1bd0>],
#  'means': []}
